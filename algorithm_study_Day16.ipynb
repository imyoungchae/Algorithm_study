# %% [markdown]
# <a href="https://colab.research.google.com/github/imyoungchae/Python_study/blob/main/algorithm_study_Day16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #탐색트리
# : 저장된 데이터에 대해 탐색, 삽입, 삭제, 갱신 등의 연산을 수행할 수 있는 자료구조
# - ***이진탐색:*** 정렬된 데이터의 중간에 위치한 항목을 기준으로 데이터를 두 부분으로 나누어가며 특정 항목을 찾는 탐색 방법
# - ***탐색연산:*** 탐색하고자 하는 키가 k라면 루트의 키와 k를 비교하는 것으로 탐색을 시작
# - ***삽입연산:*** 탐색 연산과 거의 동일하지만, 탐색 중 None을 만나면 새 노드를 생성하여 부모노드와 연결한다 이미 key가 있는 경우엔 value값만 갱신한다.
# - ***최솟값 찾기:*** 최솟값은 루트 노드로부터 왼쪽 자식을 따라 내려가며 None을 만났을 때 None의 부모가 가진 value
# - ***최솟값 삭제 연산:*** 최솟값을 가진 노드 n을 찾아낸 뒤 n의 부모 p와 n의 오른쪽 자식 c를 연결(이때 c가 None이더라도 자식으로 연결)
# - ***삭제연산:*** 삭제된 노드의 부모와 자식(들)을 연결해주어야 함.삭제되는 노드가 자식이 없는 경우,자식이 하나인 경우,자식이 둘인 경우로 나누어 delete

# %% [markdown]
# **1. 자식이 없는 경우**
#
# ![image.png](data:image/png;base64,...)
#
# - 3을 delete하고 3의 부모인 5의 왼쪽 자식에 대한 포인터를 null로 만든다
#
#
# **2. 자식이 하나인 경우**
#
# ![image.png](data:image/png;base64,...)
#
#
# - 서브 트리의 가장 오른쪽 노드인 2를 찾는다
# - 2의 부모와 연결을 끊는다.
# - 이 경우에는 부모인 1의 오른쪽 자식에 대한 포인터를 null로 만들어준다.
# - 삭제하려는 노드인 3이 부모인 5의 왼쪽에 있으므로 5의 왼쪽에 2를 연결시켜 준다.
# - 만약, 삭제하려는 노드가 부모의 오른쪽에 있었다면, 대체하는 노드를 부모의 오른쪽에 연결시켜 주어야 한다.
# - 2의 왼쪽에 원래 3의 왼쪽 자식인 1을 연결시켜 준다.
# -  3을 삭제한다
#
# ![image.png](data:image/png;base64,...)
#
# **3. 양쪽에 자식이 있는 경우**
#
# ![image.png](data:image/png;base64,...)
#
# - 대체하는 노드를 왼쪽 서브 트리의 가장 오른쪽 노드로 정하거나, 오른쪽 서브 트리의 가장 왼쪽 노드로 정한다
# - 오른쪽 서브 트리의 가장 왼쪽 노드인 11을 찾는다.
# - 11의 부모와 연결을 끊는다.
# - 이 경우에는 부모인 13의 왼쪽 자식에 대한 포인터를 null로 만들어준다.
# - 삭제하려는 노드인 10이 부모인 5의 오른쪽에 있으므로 5의 오른쪽에 11을 연결시켜 준다.
# - 11의 오른쪽에 원래 15의 오른쪽 자식인 13을, 11의 왼쪽에 원래 15의 왼쪽 자식인 8을 연결시켜 준다.
# - 10을 삭제한다.
#
# ![image.png](data:image/png;base64,...)
